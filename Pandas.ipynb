# %%
import pandas as pd

# %%
#reading data from csv file using variable df
df=pd.read_csv('com.csv')

# %%
#Reading data from a csv file
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 4 columns):
# Name          6 non-null object
# Department    4 non-null object
# Manager       4 non-null object
# Salary        6 non-null int64
# dtypes: int64(1), object(3)
# memory usage: 272.0+ bytes

# %%
# to read all data
df
# Out:
#             Name Department      Manager  Salary
# 0     Robin Hood        NaN          NaN     200
# 1  Arsene Wenger        Bar   Friar Tuck      50
# 2     Friar Tuck        Foo   Robin Hood     100
# 3    Little John        Foo   Robin Hood     100
# 4  Sam Allardyce        NaN          NaN     250
# 5  Dimi Berbatov        Foo  Little John      50

# %%
#for top 3 rows
df.head(3)
# Out:
#             Name Department     Manager  Salary
# 0     Robin Hood        NaN         NaN     200
# 1  Arsene Wenger        Bar  Friar Tuck      50
# 2     Friar Tuck        Foo  Robin Hood     100

# %%
# particular coloumn
df['Name']
# Out:
# 0       Robin Hood
# 1    Arsene Wenger
# 2       Friar Tuck
# 3      Little John
# 4    Sam Allardyce
# 5    Dimi Berbatov
# Name: Name, dtype: object

# %%
# select rows and coloumns, syntax inside braces is same as numpy
df.iloc[0:,[0,3]]
# Out:
#             Name  Salary
# 0     Robin Hood     200
# 1  Arsene Wenger      50
# 2     Friar Tuck     100
# 3    Little John     100
# 4  Sam Allardyce     250
# 5  Dimi Berbatov      50

# %%
#salary 
df['Salary']
# Out:
# 0    200
# 1     50
# 2    100
# 3    100
# 4    250
# 5     50
# Name: Salary, dtype: int64

# %%
#maximum salary
df['Salary'].max()
# Out:
# 250

# %%
#minimum salary
df['Salary'].min()
# Out:
# 50

# %%
# sum of salary
df['Salary'].sum()
# Out:
# 750

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame
